# %%
import pandas as pd

# %%
fruits = pd.Series(['Apple', 'Banana', 'Cherry', 'Orange', 'Pear'], name = "Fruit")
fruits
# Out:
# 0     Apple
# 1    Banana
# 2    Cherry
# 3    Orange
# 4      Pear
# Name: Fruit, dtype: object

# %%
qtys = pd.Series([5,7,2,9,4])
qtys
# Out:
# 0    5
# 1    7
# 2    2
# 3    9
# 4    4
# dtype: int64

# %%
inv = pd.DataFrame( { 'Fruit' : fruits, 'Quantity': qtys, 'Price' : [2.99,1.99,3.99,2.99,1.49] })
inv
# Out:
#     Fruit  Quantity  Price
# 0   Apple         5   2.99
# 1  Banana         7   1.99
# 2  Cherry         2   3.99
# 3  Orange         9   2.99
# 4    Pear         4   1.49

# %%
from IPython.display import display

display(inv)
display(inv)
# Out:
#     Fruit  Quantity  Price
# 0   Apple         5   2.99
# 1  Banana         7   1.99
# 2  Cherry         2   3.99
# 3  Orange         9   2.99
# 4    Pear         4   1.49
#     Fruit  Quantity  Price
# 0   Apple         5   2.99
# 1  Banana         7   1.99
# 2  Cherry         2   3.99
# 3  Orange         9   2.99
# 4    Pear         4   1.49

# %%
inv.iloc[1:2, 1:]
# Out:
#    Quantity  Price
# 1         7   1.99

# %%
inv.iloc[2:,0:1]
# Out:
#     Fruit
# 2  Cherry
# 3  Orange
# 4    Pear

# %%
inv.iloc[2:4]
# Out:
#     Fruit  Quantity  Price
# 2  Cherry         2   3.99
# 3  Orange         9   2.99

# %%
inv[ ['Fruit', 'Price'] ]
# Out:
#     Fruit  Price
# 0   Apple   2.99
# 1  Banana   1.99
# 2  Cherry   3.99
# 3  Orange   2.99
# 4    Pear   1.49

# %%
inv[ ['Price'] ]
# Out:
#    Price
# 0   2.99
# 1   1.99
# 2   3.99
# 3   2.99
# 4   1.49

# %%
inv['Price']
# Out:
# 0    2.99
# 1    1.99
# 2    3.99
# 3    2.99
# 4    1.49
# Name: Price, dtype: float64

# %%
inv
# Out:
#     Fruit  Quantity  Price
# 0   Apple         5   2.99
# 1  Banana         7   1.99
# 2  Cherry         2   3.99
# 3  Orange         9   2.99
# 4    Pear         4   1.49

# %%
inv['Quantity'] > 5
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# Name: Quantity, dtype: bool

# %%
inv[ inv['Quantity'] > 5 ]
# Out:
#     Fruit  Quantity  Price
# 1  Banana         7   1.99
# 3  Orange         9   2.99

# %%
fruit = input("Enter a fruit: ")
display(inv[ inv['Fruit'] == fruit ])
# Out:
# Enter a fruit: Orange
#     Fruit  Quantity  Price
# 3  Orange         9   2.99

# %%
while True:
    fruit = input("Enter a fruit: ")

    if fruit == 'quit': 
        break
    
    display(inv[ inv['Fruit'] == fruit ])
# Out:
# Enter a fruit: quit

# %%
# Loop over a data frame. one record at a time.
for row in inv.to_dict(orient='records'):
    print(f"{row['Fruit']} costs {row['Price']}.")
# Out:
# Apple costs 2.99.
# Banana costs 1.99.
# Cherry costs 3.99.
# Orange costs 2.99.
# Pear costs 1.49.

# %%
x = inv.to_dict(orient='row')
x
# Out:
# [{'Fruit': 'Apple', 'Quantity': 5, 'Price': 2.99},
#  {'Fruit': 'Banana', 'Quantity': 7, 'Price': 1.99},
#  {'Fruit': 'Cherry', 'Quantity': 2, 'Price': 3.99},
#  {'Fruit': 'Orange', 'Quantity': 9, 'Price': 2.99},
#  {'Fruit': 'Pear', 'Quantity': 4, 'Price': 1.49}]

# %%
help(inv.to_dict)
# Out:
# Help on method to_dict in module pandas.core.frame:
#
# to_dict(orient='dict', into=<class 'dict'>) method of pandas.core.frame.DataFrame instance
#     Convert the DataFrame to a dictionary.
#
#     The type of the key-value pairs can be customized with the parameters
#     (see below).
#
#     Parameters
#     ----------
#     orient : str {'dict', 'list', 'series', 'split', 'records', 'index'}
#         Determines the type of the values of the dictionary.
#
#         - 'dict' (default) : dict like {column -> {index -> value}}
#         - 'list' : dict like {column -> [values]}
#         - 'series' : dict like {column -> Series(values)}
#         - 'split' : dict like
#           {'index' -> [index], 'columns' -> [columns], 'data' -> [values]}
#         - 'records' : list like
#           [{column -> value}, ... , {column -> value}]
#         - 'index' : dict like {index -> {column -> value}}
#
#         Abbreviations are allowed. `s` indicates `series` and `sp`
# ...

# %%
dir(pd)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_hashtable',
#  '_is_numpy_dev',
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mafudge/datasets/master/superhero/superhero-movie-dataset-1978-2012.csv')
df
# Out:
#     1978                                   Superman      DC  7.3  95    84  \
# 0   1980                                Superman II      DC  6.7  88  77.5
# 1   1982                                Swamp Thing      DC  5.3  60  56.5
# 2   1983                               Superman III      DC  4.9  24  36.5
# 3   1984                                  Supergirl      DC  4.2   8  25.0
# 4   1986                            Howard the Duck  Marvel  4.3  16  29.5
# 5   1987           Superman IV: The Quest for Peace      DC  3.6  10  23.0
# 6   1989                                     Batman      DC  7.6  71  73.5
# 7   1989                  The Return of Swamp Thing      DC  3.9  40  39.5
# 8   1989                               The Punisher  Marvel  5.4  24  39.0
# 9   1992                             Batman Returns      DC  7.0  78  74.0
# 10  1995                             Batman Forever      DC  5.4  42  48.0
# ...

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# read_csv(filepath_or_buffer: Union[str, pathlib.Path, IO[~AnyStr]], sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression='infer', thousands=None, decimal: str = '.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
# ...

# %%
sh = pd.read_csv(
    'https://raw.githubusercontent.com/mafudge/datasets/master/superhero/superhero-movie-dataset-1978-2012.csv',
    names = [ 'year', 'title', 'comic', 'imdb', 'rt', 'composite', 'opening_weeked_bo', 'avg_ticket_price', 'opening_weekend_attend', 'us_pop_that_year'])


sh
# Out:
#     year                                      title   comic  imdb  rt  \
# 0   1978                                   Superman      DC   7.3  95
# 1   1980                                Superman II      DC   6.7  88
# 2   1982                                Swamp Thing      DC   5.3  60
# 3   1983                               Superman III      DC   4.9  24
# 4   1984                                  Supergirl      DC   4.2   8
# 5   1986                            Howard the Duck  Marvel   4.3  16
# 6   1987           Superman IV: The Quest for Peace      DC   3.6  10
# 7   1989                                     Batman      DC   7.6  71
# 8   1989                  The Return of Swamp Thing      DC   3.9  40
# 9   1989                               The Punisher  Marvel   5.4  24
# 10  1992                             Batman Returns      DC   7.0  78
# 11  1995                             Batman Forever      DC   5.4  42
# ...

# %%
sh.sample(5)
# Out:
#     year                  title   comic  imdb  rt  composite  \
# 23  2004           Spider-Man 2  Marvel   7.5  93       84.0
# 15  2000                  X-Men  Marvel   7.4  82       78.0
# 34  2008    The Incredible Hulk  Marvel   7.0  67       68.5
# 12  1997         Batman & Robin      DC   3.6  12       24.0
# 29  2006  X-Men: The Last Stand  Marvel   6.8  57       62.5
#
#     opening_weeked_bo  avg_ticket_price  opening_weekend_attend  \
# 23         88156227.0              6.21            1.419585e+07
# 15         54471475.0              5.39            1.010603e+07
# 34         55414050.0              7.18            7.717834e+06
# 12         42872605.0              4.59            9.340437e+06
# 29        102750665.0              6.55            1.568712e+07
#
#     us_pop_that_year
# 23         293045739
# 15         282171957
# 34         304374846
# 12         267783607
# 29         298593212

# %%
sh.head(10)
# Out:
#    year                             title   comic  imdb  rt  composite  \
# 0  1978                          Superman      DC   7.3  95       84.0
# 1  1980                       Superman II      DC   6.7  88       77.5
# 2  1982                       Swamp Thing      DC   5.3  60       56.5
# 3  1983                      Superman III      DC   4.9  24       36.5
# 4  1984                         Supergirl      DC   4.2   8       25.0
# 5  1986                   Howard the Duck  Marvel   4.3  16       29.5
# 6  1987  Superman IV: The Quest for Peace      DC   3.6  10       23.0
# 7  1989                            Batman      DC   7.6  71       73.5
# 8  1989         The Return of Swamp Thing      DC   3.9  40       39.5
# 9  1989                      The Punisher  Marvel   5.4  24       39.0
#
#    opening_weeked_bo  avg_ticket_price  opening_weekend_attend  \
# 0          7465343.0              2.34            3.190318e+06
# ...

# %%
sh.tail(10)
# Out:
#     year                               title   comic  imdb  rt  composite  \
# 39  2010                          Iron Man 2  Marvel   7.1  74       72.5
# 40  2010                           Jonah Hex      DC   4.6  13       29.5
# 41  2011  Captain America: The First Avenger  Marvel   6.8  79       73.5
# 42  2011                       Green Lantern      DC   5.9  27       43.0
# 43  2011                                Thor  Marvel   7.0  77       73.5
# 44  2011                  X-Men: First Class  Marvel   7.9  87       83.0
# 45  2012               Marvel's The Avengers  Marvel   8.7  92       89.5
# 46  2012               The Dark Knight Rises      DC   9.1  86       88.5
# 47  2012    Ghost Rider: Spirit of Vengeance  Marvel   4.5  17       31.0
# 48  2012              The Amazing Spider-Man  Marvel   7.6  74       75.0
#
#     opening_weeked_bo  avg_ticket_price  opening_weekend_attend  \
# 39        128122480.0              7.89            1.623859e+07
# ...

# %%
sh[ sh['comic'] == 'Marvel' ].tail(10)
# Out:
#     year                               title   comic  imdb  rt  composite  \
# 35  2008                            Iron Man  Marvel   7.9  94       86.5
# 36  2008                  Punisher: War Zone  Marvel   6.0  26       43.0
# 38  2009            X-Men Origins: Wolverine  Marvel   6.7  37       52.0
# 39  2010                          Iron Man 2  Marvel   7.1  74       72.5
# 41  2011  Captain America: The First Avenger  Marvel   6.8  79       73.5
# 43  2011                                Thor  Marvel   7.0  77       73.5
# 44  2011                  X-Men: First Class  Marvel   7.9  87       83.0
# 45  2012               Marvel's The Avengers  Marvel   8.7  92       89.5
# 47  2012    Ghost Rider: Spirit of Vengeance  Marvel   4.5  17       31.0
# 48  2012              The Amazing Spider-Man  Marvel   7.6  74       75.0
#
#     opening_weeked_bo  avg_ticket_price  opening_weekend_attend  \
# 35         98618668.0              7.18            1.373519e+07
# ...

# %%
sh['comic'].value_counts(normalize=True)
# Out:
# Marvel    0.591837
# DC        0.408163
# Name: comic, dtype: float64

# %%
help(sh['comic'].value_counts)
# Out:
# Help on method value_counts in module pandas.core.base:
#
# value_counts(normalize=False, sort=True, ascending=False, bins=None, dropna=True) method of pandas.core.series.Series instance
#     Return a Series containing counts of unique values.
#
#     The resulting object will be in descending order so that the
#     first element is the most frequently-occurring element.
#     Excludes NA values by default.
#
#     Parameters
#     ----------
#     normalize : bool, default False
#         If True then the object returned will contain the relative
#         frequencies of the unique values.
#     sort : bool, default True
#         Sort by frequencies.
#     ascending : bool, default False
#         Sort in ascending order.
#     bins : int, optional
#         Rather than count values, group them into half-open bins,
#         a convenience for ``pd.cut``, only works with numeric data.
#     dropna : bool, default True
#         Don't include counts of NaN.
#
#     Returns
# ...

# %%
sh2004 = sh[ sh['year'] >=2004 ]
sh2004[ sh2004['comic'].str.find("DC") >=0 ]
# Out:
#     year                  title comic  imdb  rt  composite  opening_weeked_bo  \
# 22  2004               Catwoman    DC   3.2  10       21.0         16728411.0
# 25  2005          Batman Begins    DC   8.3  85       84.0         48745440.0
# 28  2006       Superman Returns    DC   6.3  76       69.5         52535096.0
# 33  2008        The Dark Knight    DC   8.9  94       91.5        158411483.0
# 37  2009               Watchmen    DC   7.7  64       70.5         55214334.0
# 40  2010              Jonah Hex    DC   4.6  13       29.5          5379365.0
# 42  2011          Green Lantern    DC   5.9  27       43.0         53174303.0
# 46  2012  The Dark Knight Rises    DC   9.1  86       88.5        160887295.0
#
#     avg_ticket_price  opening_weekend_attend  us_pop_that_year
# 22              6.21            2.693786e+06         293045739
# 25              6.41            7.604593e+06         295753151
# 28              6.55            8.020625e+06         298593212
# ...
